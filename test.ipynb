# %%
with open("text-notes/zettel.txt", encoding='utf-8') as f:
    content = f.readlines()

# %%
content_remove_duplicates = list(set(content))
content_remove_duplicates
# Out:
# ['* I thought about and helped others, that is why people liked me more then than now\n',
#  '* “Illusory superiority” is the name behavioral scientists use for the cognitive bias that leads us to overestimate our positive qualities and discount negative ones.\n',
#  '* Curse of knowledge is the cognitive bias that describes the difficulties in communicating across differences in knowledge.79 I remember a friend trying to teach me how to play the drums.\n',
#  '* Yes!\n',
#  '* total time taking care of their\n',
#  '* At the start of a friendship/relationship I need to be completely trustworthy, if the other is not then I end it. I should have ended it with Carmen when she kissed the other guy.\n',
#  '* when we update our assumptions sometimes we get wrong data, because she told me the next time I go to garretstwon it will be with you, the next week she stop talking to me. I never trusted her again.\n',
# ...

# %%
content_remove_duplicates = []
for line in content:
    if line not in content_remove_duplicates:
        content_remove_duplicates.append(line)

# %%
new_content = [line for line in content if line.strip() != '']

# %%
len(new_content)
# Out:
# 2506

# %%
with open("text-notes/zettel.txt", encoding='utf-8') as f:
    content = f.readlines()

# %%
new_content = [line for line in content if line.strip() != '']

# %%
total_num_lines = len(new_content)
num_lines_per_heading = 50
number_headings = total_num_lines // num_lines_per_heading

# %%
number_headings
# Out:
# 14

# %%
with open("zettel-notes/zettel_set.md", "w+", encoding='utf-8') as f:
    for line in content_remove_duplicates:
        f.write(line)
